# %%
from PME import PME1D, PME2D
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

# %% [markdown]
# # One dimension

# %% [markdown]
# ## Sample solution

# %%
P = PME1D(beta=0.01, nx=32, ny =32, order=2)
print(P)
P.solve()
P.draw(P.rhoh)
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 32 x 32
#   Order: 2
#   Degrees of freedom (primal space):  4096
#   Degrees of freedom (dual space):  4225
#   Non-linear solver: brent, with interval: [0.8, 2.2]
#   PDHG iterations: 1000
# Iteration: 1000 PDHG error: 9.47118913e-08 spacetime error: 4.78747236e-06 terminal error 6.25781389e-06
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.24…

# %% [markdown]
# ## Convergence study

# %%
nx, ny = 8, 8
beta = 0.01

labels = [r'$8\times 8$', r'$16\times 16$', r'$32\times 32$', r'$64\times64$']
colors = ['r','g','b','m']

# %% [markdown]
# ### $\alpha = 1.5$

# %%
alpha = 1.5

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 1
for i in range(4):
    P1 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    if i == 0: print(P1)
    P1.solve()
    P1.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P1.terminalErr[-1]))
        print("\n")
    err0 = P1.stErr[-1]
    err1 = P1.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 1.5
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  81
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1000
# Iteration: 1000 PDHG error: 1.03635202e-08 spacetime error: 2.52482782e-03 terminal error 3.80457496e-03
#
# Iteration: 1000 PDHG error: 1.15365566e-08 spacetime error: 6.04173682e-04 terminal error 9.14679833e-04
#
# Order (ST) =  2.063149762678627
# Order (Terminal) =  2.056396540962474
#
#
# Iteration: 1000 PDHG error: 1.19466653e-08 spacetime error: 1.49632782e-04 terminal error 2.26800469e-04
#
# Order (ST) =  2.013537062603455
# Order (Terminal) =  2.0118432158014867
#
#
# Iteration: 1000 PDHG error: 1.20031890e-08 spacetime error: 3.75228845e-05 terminal error 5.69163454e-05
#
# Order (ST) =  1.995583636190798
# Order (Terminal) =  1.994508691406039

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 2
for i in range(4):
    P2 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    if i == 0: print(P2)
    P2.solve()
    P2.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P2.terminalErr[-1]))
        print("\n")
    err0 = P2.stErr[-1]
    err1 = P2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 1.5
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 2
#   Degrees of freedom (primal space):  256
#   Degrees of freedom (dual space):  289
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1500
# Iteration: 1500 PDHG error: 2.47243115e-10 spacetime error: 2.46270339e-04 terminal error 2.23591242e-04
#
# Iteration: 1500 PDHG error: 4.91713159e-09 spacetime error: 3.22244043e-05 terminal error 2.68423274e-05
#
# Order (ST) =  2.9340172866916254
# Order (Terminal) =  3.0582820057951623
#
#
# Iteration: 1500 PDHG error: 1.60292335e-10 spacetime error: 4.07165250e-06 terminal error 3.86811862e-06
#
# Order (ST) =  2.9844673463247187
# Order (Terminal) =  2.7948058266656552
#
#
# Iteration: 1500 PDHG error: 4.65785188e-11 spacetime error: 5.10303148e-07 terminal error 4.85777574e-07
#
# Order (ST) =  2.996187991158237
# Order (Terminal) =  2.9932642439460686

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 3
for i in range(4):
    P3 = PME1D(
        order   = order,
        maxIter = nIter + 1, 
        alpha   = alpha, 
        beta    = beta, 
        nx      = nx * 2 ** i, 
        ny      = ny * 2 ** i,
        brentMin = 0,
        brentMax = 3
    )
    if i == 0: print(P3)
    P3.solve()
    P3.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P3.terminalErr[-1]))
        print("\n")
    err0 = P3.stErr[-1]
    err1 = P3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 1.5
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 3
#   Degrees of freedom (primal space):  576
#   Degrees of freedom (dual space):  625
#   Non-linear solver: brent, with interval: [0, 3]
#   PDHG iterations: 1800
# Iteration: 1800 PDHG error: 1.84428917e-10 spacetime error: 1.16988263e-05 terminal error 1.12417259e-05
#
# Iteration: 1800 PDHG error: 8.27176105e-11 spacetime error: 7.42036397e-07 terminal error 7.08047733e-07
#
# Order (ST) =  3.978730028379806
# Order (Terminal) =  3.9888731061977696
#
#
# Iteration: 1800 PDHG error: 5.65467673e-11 spacetime error: 4.67235638e-08 terminal error 4.45121885e-08
#
# Order (ST) =  3.989267729333185
# Order (Terminal) =  3.9915742835332817
#
#
# Iteration: 1800 PDHG error: 3.94295707e-11 spacetime error: 8.42695252e-09 terminal error 5.06147229e-09
#
# Order (ST) =  2.4710674169574642
# Order (Terminal) =  3.1365714296598566

# %% [markdown]
# ### $\alpha = 2$

# %%
alpha = 2

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 1
for i in range(4):
    PP1 = PME1D(
        order = order, 
        maxIter = nIter + 1, 
        alpha = alpha, 
        beta = beta, 
        nx = nx * 2 ** i, 
        ny = ny * 2 ** i)
    if i == 0: print(PP1)
    PP1.solve()
    PP1.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP1.terminalErr[-1]))
        print("\n")
    err0 = PP1.stErr[-1]
    err1 = PP1.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  81
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1000
# Iteration: 1000 PDHG error: 8.03768379e-08 spacetime error: 3.59925956e-03 terminal error 4.96724344e-03
#
# Iteration: 1000 PDHG error: 9.08648257e-08 spacetime error: 8.70164336e-04 terminal error 1.20941868e-03
#
# Order (ST) =  2.048340353285602
# Order (Terminal) =  2.0381316825976024
#
#
# Iteration: 1000 PDHG error: 9.38190950e-08 spacetime error: 2.16665578e-04 terminal error 3.02185491e-04
#
# Order (ST) =  2.0058179202471633
# Order (Terminal) =  2.0008074699678473
#
#
# Iteration: 1000 PDHG error: 9.45569304e-08 spacetime error: 5.50639339e-05 terminal error 7.74553922e-05
#
# Order (ST) =  1.9762903808120376
# Order (Terminal) =  1.963996810931006

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 2
for i in range(4):
    PP2 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    if i == 0: print(PP2)
    PP2.solve()
    PP2.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP2.terminalErr[-1]))
        print("\n")
    err0 = PP2.stErr[-1]
    err1 = PP2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 2
#   Degrees of freedom (primal space):  256
#   Degrees of freedom (dual space):  289
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1500
# Iteration: 1500 PDHG error: 8.53976445e-09 spacetime error: 2.48128117e-04 terminal error 1.99238298e-04
#
# Iteration: 1500 PDHG error: 4.60492311e-09 spacetime error: 3.22718803e-05 terminal error 2.73423347e-05
#
# Order (ST) =  2.9427356855089384
# Order (Terminal) =  2.865286650931788
#
#
# Iteration: 1500 PDHG error: 3.05840020e-10 spacetime error: 4.07320872e-06 terminal error 3.86930589e-06
#
# Order (ST) =  2.9860399894932073
# Order (Terminal) =  2.8209897451156
#
#
# Iteration: 1500 PDHG error: 3.26790928e-10 spacetime error: 5.10440082e-07 terminal error 4.85641596e-07
#
# Order (ST) =  2.9963522146028
# Order (Terminal) =  2.9941108853447447

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 3
for i in range(4):
    PP3 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    if i == 0: print(PP3)
    PP3.solve()
    PP3.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP3.terminalErr[-1]))
        print("\n")
    err0 = PP3.stErr[-1]
    err1 = PP3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 3
#   Degrees of freedom (primal space):  576
#   Degrees of freedom (dual space):  625
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1800
# Iteration: 1800 PDHG error: 1.86562987e-10 spacetime error: 1.17574289e-05 terminal error 1.12411590e-05
#
# Iteration: 1800 PDHG error: 7.93620725e-11 spacetime error: 7.43068292e-07 terminal error 7.08553080e-07
#
# Order (ST) =  3.983933993742929
# Order (Terminal) =  3.9877710428003157
#
#
# Iteration: 1800 PDHG error: 7.06137371e-11 spacetime error: 4.68690261e-08 terminal error 4.48843551e-08
#
# Order (ST) =  3.9867880855278734
# Order (Terminal) =  3.980591361365662
#
#
# Iteration: 1800 PDHG error: 2.61191069e-11 spacetime error: 6.31081585e-09 terminal error 7.84521715e-09
#
# Order (ST) =  2.8927363855662263
# Order (Terminal) =  2.516327381535743

# %% [markdown]
# # Two dimensions

# %% [markdown]
# ## Sample solution

# %%
P = PME2D(beta = 0.005, nx = 8, ny = 8, nz = 8, order=1)
P.solve()

# %% [markdown]
# ## Convergence study

# %%
nx, ny, nz = 4, 4, 4
beta = 0.005

colors = ['darkorange','r','g']
labels = [r'$4\times 4 \times 4$',r'$8\times 8 \times 8$', r'$16\times 16 \times 16$']

# %% [markdown]
# ### $\alpha = 1.5$

# %%
alpha = 1.5

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 1
for i in range(3):
    P21 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P21.solve()
    P21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P21.terminalErr[-1]))
        print("\n")
    err0 = P21.stErr[-1]
    err1 = P21.terminalErr[-1]
    
axs[0].legend()
plt.show()

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2000
order = 2
for i in range(3):
    P22 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P22.solve()
    P22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P22.terminalErr[-1]))
        print("\n")
    err0 = P22.stErr[-1]
    err1 = P22.terminalErr[-1]
    
axs[0].legend()
plt.show()

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2500
order = 3
for i in range(3):
    P23 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P23.solve()
    P23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P23.terminalErr[-1]))
        print("\n")
    err0 = P23.stErr[-1]
    err1 = P23.terminalErr[-1]
    
axs[0].legend()
plt.show()

# %% [markdown]
# ### $\alpha = 2$

# %%
alpha = 2

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 1
for i in range(3):
    PP21 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP21.solve()
    PP21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP21.terminalErr[-1]))
        print("\n")
    err0 = PP21.stErr[-1]
    err1 = PP21.terminalErr[-1]
    
axs[0].legend()
plt.show()

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2500
order = 2
for i in range(3):
    PP22 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP22.solve()
    PP22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP22.terminalErr[-1]))
        print("\n")
    err0 = PP22.stErr[-1]
    err1 = PP22.terminalErr[-1]
    
axs[0].legend()
plt.show()

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 3200
order = 3
for i in range(3):
    PP23 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP23.solve()
    PP23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP23.terminalErr[-1]))
        print("\n")
    err0 = PP23.stErr[-1]
    err1 = PP23.terminalErr[-1]
    
axs[0].legend()
plt.show()
