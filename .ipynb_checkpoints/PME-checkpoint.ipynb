# %%
from PME import PME1D, PME2D
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

# %% [markdown]
# # One dimension

# %% [markdown]
# ## Sample solution

# %%
P = PME1D(beta=0.01, nx=32, ny =32, order=2)
print(P)
P.solve()
P.draw(P.rhoh)
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 32 x 32
#   Order: 2
#   Degrees of freedom (primal space):  4096
#   Degrees of freedom (dual space):  4225
#   Non-linear solver: newton
#   PDHG iterations: 1000
# Iteration: 1000 PDHG error: 9.47310780e-08 spacetime error: 4.78986744e-06 terminal error 6.26346609e-06
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
P = PME1D(beta=0.01, nx=32, ny=32, order=2, nonLinearSolver='brent')
print(P)
P.solve()
P.draw(P.rhoh)
# Out:
# Porous Medium Equation
#   C: 1
#   alpha: 2
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 32 x 32
#   Order: 2
#   Degrees of freedom (primal space):  4096
#   Degrees of freedom (dual space):  4225
#   Non-linear solver: brent with interval: [0.8, 2.2]
#   PDHG iterations: 1000
# Iteration: 1000 PDHG error: 9.47118913e-08 spacetime error: 4.78747236e-06 terminal error 6.25781389e-06
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
P.saveVTK("PME1D_alpha_2_beta_0p01_order_2_32x32")

# %% [markdown]
# ## Convergence study

# %%
nx, ny = 8, 8
beta = 0.01

labels = [r'$8\times 8$', r'$16\times 16$', r'$32\times 32$', r'$64\times64$']
colors = ['r','g','b','m']

# %% [markdown]
# ### $\alpha = 1.5$

# %%
alpha = 1.5

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 1
for i in range(4):
    P1 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    P1.solve()
    P1.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P1.terminalErr[-1]))
        print("\n")
    err0 = P1.stErr[-1]
    err1 = P1.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1000 PDHG error: 5.22513810e-09 spacetime error: 2.52470017e-03 terminal error 3.80436496e-03
#
# Iteration: 1000 PDHG error: 5.92284854e-09 spacetime error: 6.04037935e-04 terminal error 9.14455822e-04
#
# Order (ST) =  2.063401001786788
# Order (Terminal) =  2.0566702733565303
#
#
# Iteration: 1000 PDHG error: 6.10825224e-09 spacetime error: 1.49496167e-04 terminal error 2.26575014e-04
#
# Order (ST) =  2.014530658496622
# Order (Terminal) =  2.0129247012559675
#
#
# Iteration: 1000 PDHG error: 6.15540552e-09 spacetime error: 3.73853060e-05 terminal error 5.66894085e-05
#
# Order (ST) =  1.9995652520916418
# Order (Terminal) =  1.9988376507840877

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 1
for i in range(4):
    P1 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nonLinearSolver = "brent")
    P1.solve()
    P1.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P1.terminalErr[-1]))
        print("\n")
    err0 = P1.stErr[-1]
    err1 = P1.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1000 PDHG error: 1.01382747e-09 spacetime error: 1.03551082e-01 terminal error 1.43711283e-01
#
# Iteration: 1000 PDHG error: 3.10719250e-08 spacetime error: 1.07389590e-01 terminal error 1.39383871e-01
#
# Order (ST) =  -0.05251151788483273
# Order (Terminal) =  0.04410970862907056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 for i in range(4):
#       6     P1 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nonLinearSolver = "brent")
# ----> 7     P1.solve()
#       8     P1.plotErr(axs, labels[i], colors[i])
#       9     if i > 0:
#
# File ~/Documents/Code/Github/WassersteinGradientFlows/PDE.py:268, in PDE.solve(self)
#     266 with TaskManager():
#     267     for i in range(1,self.maxIter+1):
# --> 268         self.timestep()
#     269         if ( i % self.printNum)==0:
#     270             self.err = max(max(self.drhoTh), -min(self.drhoTh))
#
# File ~/Documents/Code/Github/WassersteinGradientFlows/PDE.py:240, in PDE.timestep(self)
#     238     solvers.Newton(self.b, self.rhoh, printing=False)
#     239 else:
# --> 240     self.rhoh.vec.FV().NumPy()[:] = self.solveRho(self.mh01, self.sh0, self.nh01, self.rhoh0)
#     242 ### Update mh, nh, sh
#     243 self.mh1.Interpolate(self.V1(self.rhoh) * self.mh01 / ( 1 + self.V1(self.rhoh) ) )
#
# File ~/Documents/Code/Github/WassersteinGradientFlows/PME.py:135, in PME1D.solveRho(self, m, s, n, rhoBar)
#     133     mbar2, nbar2, sbar2 = m_flat[idx]**2, n_flat[idx]**2, s_flat[idx]**2
#     134     obj_fixed_idx = lambda rho : F(rho, rho_bar_flat[idx], mbar2, nbar2, sbar2)
# --> 135     rho_flat[idx] = brent.brent_find_minima(obj_fixed_idx, 1e-12, 2.0)
#     137 return rho_flat
#
# File ~/Documents/Code/Github/WassersteinGradientFlows/PME.py:134, in PME1D.solveRho.<locals>.<lambda>(rho)
#     132 for idx in range(m_flat.shape[0]):
#     133     mbar2, nbar2, sbar2 = m_flat[idx]**2, n_flat[idx]**2, s_flat[idx]**2
# --> 134     obj_fixed_idx = lambda rho : F(rho, rho_bar_flat[idx], mbar2, nbar2, sbar2)
#     135     rho_flat[idx] = brent.brent_find_minima(obj_fixed_idx, 1e-12, 2.0)
#     137 return rho_flat
#
# KeyboardInterrupt:

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 2
for i in range(4):
    P2 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    P2.solve()
    P2.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P2.terminalErr[-1]))
        print("\n")
    err0 = P2.stErr[-1]
    err1 = P2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1500 PDHG error: 1.44977363e-10 spacetime error: 2.46270779e-04 terminal error 2.23591185e-04
#
# Iteration: 1500 PDHG error: 4.82257745e-09 spacetime error: 3.22244059e-05 terminal error 2.68253992e-05
#
# Order (ST) =  2.9340197938442985
# Order (Terminal) =  3.0591917671411495
#
#
# Iteration: 1500 PDHG error: 7.45727924e-11 spacetime error: 4.07174263e-06 terminal error 3.86781550e-06
#
# Order (ST) =  2.9844354820770547
# Order (Terminal) =  2.7940087609429423
#
#
# Iteration: 1500 PDHG error: 8.48099369e-12 spacetime error: 5.10332640e-07 terminal error 4.85808437e-07
#
# Order (ST) =  2.9961365497504757
# Order (Terminal) =  2.993059524750497

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 3
for i in range(4):
    P3 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    P3.solve()
    P3.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P3.terminalErr[-1]))
        print("\n")
    err0 = P3.stErr[-1]
    err1 = P3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1800 PDHG error: 3.75255382e-12 spacetime error: 1.16988724e-05 terminal error 1.12417660e-05
#
# Iteration: 1800 PDHG error: 2.97206704e-13 spacetime error: 7.42051485e-07 terminal error 7.08042630e-07
#
# Order (ST) =  3.9787063789758896
# Order (Terminal) =  3.988888650759207
#
#
# Iteration: 1800 PDHG error: 1.72528658e-13 spacetime error: 4.65531731e-08 terminal error 4.43326149e-08
#
# Order (ST) =  3.9945678756133107
# Order (Terminal) =  3.9973958598118293
#
#
# Iteration: 1800 PDHG error: 1.71418435e-13 spacetime error: 2.91236946e-09 terminal error 2.77380221e-09
#
# Order (ST) =  3.998614212395862
# Order (Terminal) =  3.9984316394914847

# %% [markdown]
# ### $\alpha = 2$

# %%
alpha = 2

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 1
for i in range(4):
    PP1 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    PP1.solve()
    PP1.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP1.terminalErr[-1]))
        print("\n")
    err0 = PP1.stErr[-1]
    err1 = PP1.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1000 PDHG error: 4.52035159e-08 spacetime error: 3.59878463e-03 terminal error 4.96629173e-03
#
# Iteration: 1000 PDHG error: 5.14153542e-08 spacetime error: 8.69623973e-04 terminal error 1.20834000e-03
#
# Order (ST) =  2.0490461477680846
# Order (Terminal) =  2.039142559643619
#
#
# Iteration: 1000 PDHG error: 5.31486586e-08 spacetime error: 2.16103286e-04 terminal error 3.01061322e-04
#
# Order (ST) =  2.00867070187103
# Order (Terminal) =  2.0048971731763645
#
#
# Iteration: 1000 PDHG error: 5.35942956e-08 spacetime error: 5.44778961e-05 terminal error 7.62702587e-05
#
# Order (ST) =  1.9879781170723179
# Order (Terminal) =  1.9808648748488156

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 2
for i in range(4):
    PP2 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    PP2.solve()
    PP2.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP2.terminalErr[-1]))
        print("\n")
    err0 = PP2.stErr[-1]
    err1 = PP2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1500 PDHG error: 8.43221803e-09 spacetime error: 2.48128198e-04 terminal error 1.99226356e-04
#
# Iteration: 1500 PDHG error: 4.55878735e-09 spacetime error: 3.22718125e-05 terminal error 2.73401133e-05
#
# Order (ST) =  2.9427391841606583
# Order (Terminal) =  2.8653173934818112
#
#
# Iteration: 1500 PDHG error: 1.78789761e-10 spacetime error: 4.07322988e-06 terminal error 3.86927212e-06
#
# Order (ST) =  2.9860294659853555
# Order (Terminal) =  2.8208851203228953
#
#
# Iteration: 1500 PDHG error: 1.69756209e-10 spacetime error: 5.10432381e-07 terminal error 4.85628485e-07
#
# Order (ST) =  2.9963814778166626
# Order (Terminal) =  2.994137240658791

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 3
for i in range(4):
    PP3 = PME1D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i)
    PP3.solve()
    PP3.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP3.terminalErr[-1]))
        print("\n")
    err0 = PP3.stErr[-1]
    err1 = PP3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1800 PDHG error: 7.23821003e-12 spacetime error: 1.17575610e-05 terminal error 1.12411967e-05
#
# Iteration: 1800 PDHG error: 5.80469006e-12 spacetime error: 7.43019871e-07 terminal error 7.08528610e-07
#
# Order (ST) =  3.9840442087612535
# Order (Terminal) =  3.9878257129019046
#
#
# Iteration: 1800 PDHG error: 5.31452660e-12 spacetime error: 4.65700160e-08 terminal error 4.42869803e-08
#
# Order (ST) =  3.9959275118035427
# Order (Terminal) =  3.999871574331992
#
#
# Iteration: 1800 PDHG error: 5.31275024e-12 spacetime error: 2.91572854e-09 terminal error 2.78307636e-09
#
# Order (ST) =  3.9974730618028524
# Order (Terminal) =  3.9921302297955967

# %% [markdown]
# # Two dimensions

# %% [markdown]
# ## Sample solution

# %%
P = PME2D(beta = 0.005, nx = 8, ny = 8, nz = 8, order=1)
P.solve()
# Out:
# Iteration: 1000 PDHG error: 6.93001835e-06 spacetime error: 2.69350671e-03 terminal error 3.82351305e-03

# %% [markdown]
# ## Convergence study

# %%
nx, ny, nz = 4, 4, 4
beta = 0.005

colors = ['darkorange','r','g']
labels = [r'$4\times 4 \times 4$',r'$8\times 8 \times 8$', r'$16\times 16 \times 16$']

# %% [markdown]
# ### $\alpha = 1.5$

# %%
alpha = 1.5

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1500
order = 1
for i in range(3):
    P21 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P21.solve()
    P21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P21.terminalErr[-1]))
        print("\n")
    err0 = P21.stErr[-1]
    err1 = P21.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1500 PDHG error: 3.96672553e-08 spacetime error: 8.64297372e-03 terminal error 1.26648757e-02
#
# Iteration: 1500 PDHG error: 6.95901594e-08 spacetime error: 1.79062375e-03 terminal error 2.70211659e-03
#
# Order (ST) =  2.271065545452194
# Order (Terminal) =  2.2286710839481407
#
#
# Iteration: 1500 PDHG error: 8.08244358e-08 spacetime error: 4.30431437e-04 terminal error 6.52913352e-04
#
# Order (ST) =  2.0566068723620714
# Order (Terminal) =  2.0491264752050697

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2000
order = 2
for i in range(3):
    P22 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P22.solve()
    P22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P22.terminalErr[-1]))
        print("\n")
    err0 = P22.stErr[-1]
    err1 = P22.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 2000 PDHG error: 2.68717348e-09 spacetime error: 1.44224810e-03 terminal error 1.52800721e-03
#
# Iteration: 2000 PDHG error: 3.07534764e-09 spacetime error: 2.44479358e-04 terminal error 2.33810575e-04
#
# Order (ST) =  2.5605347971061176
# Order (Terminal) =  2.708239267413328
#
#
# Iteration: 2000 PDHG error: 4.53322968e-09 spacetime error: 3.22021993e-05 terminal error 2.79690051e-05
#
# Order (ST) =  2.9244815317413706
# Order (Terminal) =  3.0634393397143085

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2500
order = 3
for i in range(3):
    P23 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    P23.solve()
    P23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/P23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/P23.terminalErr[-1]))
        print("\n")
    err0 = P23.stErr[-1]
    err1 = P23.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 2500 PDHG error: 1.11805232e-10 spacetime error: 1.69621660e-04 terminal error 1.68030114e-04
#
# Iteration: 2500 PDHG error: 1.14180221e-10 spacetime error: 1.14980904e-05 terminal error 1.11482670e-05
#
# Order (ST) =  3.8828542261496226
# Order (Terminal) =  3.913828454894458
#
#
# Iteration: 2500 PDHG error: 9.88001903e-11 spacetime error: 7.38628346e-07 terminal error 7.06287110e-07
#
# Order (ST) =  3.960401833767859
# Order (Terminal) =  3.980420876914286

# %% [markdown]
# ### $\alpha = 2$

# %%
alpha = 2

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1800
order = 1
for i in range(3):
    PP21 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP21.solve()
    PP21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP21.terminalErr[-1]))
        print("\n")
    err0 = PP21.stErr[-1]
    err1 = PP21.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 1800 PDHG error: 3.97560046e-08 spacetime error: 1.17040269e-02 terminal error 1.55131061e-02
#
# Iteration: 1800 PDHG error: 6.44063981e-08 spacetime error: 2.54573428e-03 terminal error 3.51361116e-03
#
# Order (ST) =  2.2008512462101453
# Order (Terminal) =  2.1424611356937984
#
#
# Iteration: 1800 PDHG error: 7.30772600e-08 spacetime error: 6.15641197e-04 terminal error 8.56110996e-04
#
# Order (ST) =  2.047920160217492
# Order (Terminal) =  2.037084779274475

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 2500
order = 2
for i in range(3):
    PP22 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP22.solve()
    PP22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP22.terminalErr[-1]))
        print("\n")
    err0 = PP22.stErr[-1]
    err1 = PP22.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 2500 PDHG error: 1.20287069e-09 spacetime error: 1.52349231e-03 terminal error 1.56071582e-03
#
# Iteration: 2500 PDHG error: 1.99101524e-09 spacetime error: 2.45863748e-04 terminal error 2.29070633e-04
#
# Order (ST) =  2.631451285832275
# Order (Terminal) =  2.768343451571335
#
#
# Iteration: 2500 PDHG error: 4.59808391e-09 spacetime error: 3.22168438e-05 terminal error 2.66625832e-05
#
# Order (ST) =  2.9319719558086255
# Order (Terminal) =  3.1029040473573484

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 3200
order = 3
for i in range(3):
    PP23 = PME2D(order = order, maxIter = nIter + 1, alpha = alpha, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    PP23.solve()
    PP23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/PP23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/PP23.terminalErr[-1]))
        print("\n")
    err0 = PP23.stErr[-1]
    err1 = PP23.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Iteration: 3200 PDHG error: 2.27629027e-11 spacetime error: 1.73646557e-04 terminal error 1.70156838e-04
#
# Iteration: 3200 PDHG error: 2.44690934e-11 spacetime error: 1.15969888e-05 terminal error 1.11456949e-05
#
# Order (ST) =  3.904331655935485
# Order (Terminal) =  3.932306654744894
#
#
# Iteration: 3200 PDHG error: 1.23013288e-09 spacetime error: 7.76766236e-07 terminal error 7.26776240e-07
#
# Order (ST) =  3.900125946359322
# Order (Terminal) =  3.938831504574528
