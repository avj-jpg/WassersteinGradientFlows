# %%
from HEAT import HEAT1D, HEAT2D
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

# %% [markdown]
# # One dimension

# %% [markdown]
# ## Sample solution

# %%
H = HEAT1D(beta = 0.025, nx = 32, ny = 32, order = 2)
print(H)
H.solve()
H.draw(H.rhoh)
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 32 x 32
#   Order: 2
#   Degrees of freedom (primal space):  4096
#   Degrees of freedom (dual space):  4225
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 1.28365207e-10 spacetime error: 1.40260733e-05 terminal error 7.89914322e-06
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
H = HEAT1D(beta = 0.025, nx = 32, ny = 32, order = 2, nonLinearSolver = "newton")
H.solve()
#H.draw(H.rhoh)
# Out:
# Iteration: 1000 PDHG error: 1.14665832e-10 spacetime error: 1.40260678e-05 terminal error 7.89914144e-06

# %%
H.saveVTK("HEAT1D_beta_0p025_order_2_32x32")

# %% [markdown]
# ## Convergence study

# %%
nx, ny = 8, 8
beta = 0.025

labels = [r'$8\times 8$', r'$16\times 16$', r'$32\times 32$', r'$64\times64$']
colors = ['r','g','b','m']

# %% [markdown]
# ### Brent's method

# %% [markdown]
#  $p = 1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 600
order = 1
for i in range(4):
    H1 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i)
    if i == 0: print(H1)
    H1.solve()
    H1.plotErr(axs,labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H1.terminalErr[-1]))
        print("\n")
    err0 = H1.stErr[-1]
    err1 = H1.terminalErr[-1]
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  81
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 600
#
#
# Iteration:  600 PDHG error: 5.10350651e-11 spacetime error: 1.01822642e-02 terminal error 1.32439159e-02
#
# Iteration:  600 PDHG error: 9.75096115e-10 spacetime error: 2.45682579e-03 terminal error 3.22195787e-03
#
# Order (ST) =  2.051190946998881
# Order (Terminal) =  2.0393202153678587
#
#
# Iteration:  600 PDHG error: 2.19173568e-11 spacetime error: 6.08671504e-04 terminal error 8.00159204e-04
#
# Order (ST) =  2.0130598304779945
# Order (Terminal) =  2.0095786520889853
#
#
# Iteration:  600 PDHG error: 2.45439224e-11 spacetime error: 1.51822620e-04 terminal error 1.99709572e-04
#
# Order (ST) =  2.003277068651436
# Order (Terminal) =  2.0023835900834634

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 800
order = 2
for i in range(4):
    H2 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i)
    if i == 0: print(H2)
    H2.solve()
    H2.plotErr(axs,labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H2.terminalErr[-1]))
        print("\n")
    err0 = H2.stErr[-1]
    err1 = H2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 2
#   Degrees of freedom (primal space):  256
#   Degrees of freedom (dual space):  289
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 800
#
#
# Iteration:  800 PDHG error: 5.83769282e-08 spacetime error: 8.69109077e-04 terminal error 3.36815464e-04
#
# Iteration:  800 PDHG error: 2.61771500e-08 spacetime error: 1.11582399e-04 terminal error 5.72315190e-05
#
# Order (ST) =  2.9614277842696883
# Order (Terminal) =  2.5570765755619593
#
#
# Iteration:  800 PDHG error: 1.35095268e-10 spacetime error: 1.40260616e-05 terminal error 7.90159900e-06
#
# Order (ST) =  2.9919275929521723
# Order (Terminal) =  2.8565933595206063
#
#
# Iteration:  800 PDHG error: 1.07509557e-11 spacetime error: 1.75582257e-06 terminal error 9.86380566e-07
#
# Order (ST) =  2.997891000535096
# Order (Terminal) =  3.0019283517440734

# %% [markdown]
# $p =3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 3
for i in range(4):
    H3 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i)
    if i == 0: print(H3)
    H3.solve()
    H3.plotErr(axs, labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H3.terminalErr[-1]))
        print("\n")
    err0 = H3.stErr[-1]
    err1 = H3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 3
#   Degrees of freedom (primal space):  576
#   Degrees of freedom (dual space):  625
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 3.41945006e-09 spacetime error: 4.18459768e-05 terminal error 2.31601774e-05
#
# Iteration: 1000 PDHG error: 3.89354105e-11 spacetime error: 2.58337476e-06 terminal error 1.46280776e-06
#
# Order (ST) =  4.01776007659168
# Order (Terminal) =  3.9848342105101042
#
#
# Iteration: 1000 PDHG error: 1.67877934e-11 spacetime error: 1.60660011e-07 terminal error 9.15169173e-08
#
# Order (ST) =  4.007174160939419
# Order (Terminal) =  3.9985579187470894
#
#
# Iteration: 1000 PDHG error: 6.34226005e-12 spacetime error: 1.00501424e-08 terminal error 5.80287334e-09
#
# Order (ST) =  3.998723024150497
# Order (Terminal) =  3.9791991131046327

# %% [markdown]
# ### Newton's method

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 600
order = 1
for i in range(4):
    H1 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i, nonLinearSolver = "newton")
    if i == 0: print(H1)
    H1.solve()
    H1.plotErr(axs,labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H1.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H1.terminalErr[-1]))
        print("\n")
    err0 = H1.stErr[-1]
    err1 = H1.terminalErr[-1]
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  81
#   Non-linear solver: newton
#   PDHG iterations: 600
#
#
# Iteration:  600 PDHG error: 1.21935795e-12 spacetime error: 1.01822641e-02 terminal error 1.32439159e-02
#
# Iteration:  600 PDHG error: 8.93717544e-10 spacetime error: 2.45682562e-03 terminal error 3.22195787e-03
#
# Order (ST) =  2.0511910283773513
# Order (Terminal) =  2.0393202161829427
#
#
# Iteration:  600 PDHG error: 1.33026923e-12 spacetime error: 6.08671375e-04 terminal error 8.00159165e-04
#
# Order (ST) =  2.013060036307507
# Order (Terminal) =  2.0095787195627888
#
#
# Iteration:  600 PDHG error: 1.41686662e-12 spacetime error: 1.51822489e-04 terminal error 1.99709527e-04
#
# Order (ST) =  2.0032780062676063
# Order (Terminal) =  2.0023838480533316

# %% [markdown]
# $p=2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 800
order = 2
for i in range(4):
    H2 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i, nonLinearSolver = "newton")
    if i == 0: print(H2)
    H2.solve()
    H2.plotErr(axs,labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H2.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H2.terminalErr[-1]))
        print("\n")
    err0 = H2.stErr[-1]
    err1 = H2.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 2
#   Degrees of freedom (primal space):  256
#   Degrees of freedom (dual space):  289
#   Non-linear solver: newton
#   PDHG iterations: 800
#
#
# Iteration:  800 PDHG error: 5.83533883e-08 spacetime error: 8.69109058e-04 terminal error 3.36815452e-04
#
# Iteration:  800 PDHG error: 2.61438011e-08 spacetime error: 1.11582411e-04 terminal error 5.72315167e-05
#
# Order (ST) =  2.9614275917941333
# Order (Terminal) =  2.5570765808016844
#
#
# Iteration:  800 PDHG error: 1.21292199e-10 spacetime error: 1.40260673e-05 terminal error 7.90159749e-06
#
# Order (ST) =  2.991927166797586
# Order (Terminal) =  2.8565935792376473
#
#
# Iteration:  800 PDHG error: 4.17099688e-12 spacetime error: 1.75581340e-06 terminal error 9.86380016e-07
#
# Order (ST) =  2.997899125674224
# Order (Terminal) =  3.0019288798280286

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 3
for i in range(4):
    H3 = HEAT1D(order = order, maxIter = nIter + 1, beta = beta, nx = nx*2**i, ny = ny*2**i, nonLinearSolver = "newton")
    if i == 0: print(H3)
    H3.solve()
    H3.plotErr(axs, labels[i], colors[i])
    if i >0:
        print('Order (ST) = ', np.log2(err0/H3.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H3.terminalErr[-1]))
        print("\n")
    err0 = H3.stErr[-1]
    err1 = H3.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1]
#   Discretization size: 8 x 8
#   Order: 3
#   Degrees of freedom (primal space):  576
#   Degrees of freedom (dual space):  625
#   Non-linear solver: newton
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 3.37567863e-09 spacetime error: 4.18459744e-05 terminal error 2.31601839e-05
#
# Iteration: 1000 PDHG error: 3.52193830e-11 spacetime error: 2.58337453e-06 terminal error 1.46280779e-06
#
# Order (ST) =  4.01776012030276
# Order (Terminal) =  3.98483459231696
#
#
# Iteration: 1000 PDHG error: 1.50190971e-12 spacetime error: 1.60665477e-07 terminal error 9.15171961e-08
#
# Order (ST) =  4.007124949633429
# Order (Terminal) =  3.9985535516773894
#
#
# Iteration: 1000 PDHG error: 2.48023824e-13 spacetime error: 1.00260005e-08 terminal error 5.80204770e-09
#
# Order (ST) =  4.002241852073343
# Order (Terminal) =  3.979408790614019

# %% [markdown]
# # Two dimensions

# %% [markdown]
# ## Sample solution

# %%
H = HEAT2D(beta = 0.025, nx = 8, ny = 8, nz = 8, order=1)
print(H)
H.solve()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.025
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 8 x 8 x 8
#   Order: 1
#   Degrees of freedom (primal space):  512
#   Degrees of freedom (dual space):  729
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 1.70437844e-08 spacetime error: 7.70141658e-03 terminal error 7.05076749e-03

# %%
H = HEAT2D(beta = 0.025, nx = 8, ny = 8, nz = 8, order=1, nonLinearSolver="brent")
H.solve()
# Out:
# Iteration: 1000 PDHG error: 1.70499104e-08 spacetime error: 7.70141639e-03 terminal error 7.05076713e-03

# %% [markdown]
# ## Convergence Study

# %%
nx, ny, nz = 4, 4, 4
beta = 0.01

colors = ['darkorange','r','g']
labels = [r'$4\times 4 \times 4$',r'$8\times 8 \times 8$', r'$16\times 16 \times 16$']

# %% [markdown]
# ### Brent's method

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 600
order = 1
for i in range(3):
    H21 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    if i == 0: print(H21)
    H21.solve()
    H21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H21.terminalErr[-1]))
        print("\n")
    err0 = H21.stErr[-1]
    err1 = H21.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  125
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 600
#
#
# Iteration:  600 PDHG error: 1.41638518e-07 spacetime error: 3.20482292e-02 terminal error 4.33296925e-02
#
# Iteration:  600 PDHG error: 3.52193528e-07 spacetime error: 6.83720607e-03 terminal error 9.43160948e-03
#
# Order (ST) =  2.2287658307492233
# Order (Terminal) =  2.199780109618316
#
#
# Iteration:  600 PDHG error: 5.58604769e-07 spacetime error: 1.63293896e-03 terminal error 2.27995432e-03
#
# Order (ST) =  2.0659360446670187
# Order (Terminal) =  2.048499066918616

# %% [markdown]
# $ p = 2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 800
order = 2
for i in range(3):
    H22 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    if i == 0: print(H22)
    H22.solve()
    H22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H22.terminalErr[-1]))
        print("\n")
    err0 = H22.stErr[-1]
    err1 = H22.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 2
#   Degrees of freedom (primal space):  512
#   Degrees of freedom (dual space):  729
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 800
#
#
# Iteration:  800 PDHG error: 1.82508690e-08 spacetime error: 5.78213554e-03 terminal error 4.39341298e-03
#
# Iteration:  800 PDHG error: 3.26422387e-08 spacetime error: 9.19274189e-04 terminal error 5.82699395e-04
#
# Order (ST) =  2.6530352884149804
# Order (Terminal) =  2.9145184006388853
#
#
# Iteration:  800 PDHG error: 5.10147107e-08 spacetime error: 1.19933009e-04 terminal error 7.48426026e-05
#
# Order (ST) =  2.9382664448751523
# Order (Terminal) =  2.960820178995323

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 3
for i in range(3):
    H23 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i)
    if i == 0: print(H23)
    H23.solve()
    H23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H23.terminalErr[-1]))
        print("\n")
    err0 = H23.stErr[-1]
    err1 = H23.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 3
#   Degrees of freedom (primal space):  1728
#   Degrees of freedom (dual space):  2197
#   Non-linear solver: brent, with interval: [0.4, 1.6]
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 1.82591098e-09 spacetime error: 6.40997478e-04 terminal error 3.89553272e-04
#
# Iteration: 1000 PDHG error: 2.32021247e-09 spacetime error: 4.28598129e-05 terminal error 2.88149455e-05
#
# Order (ST) =  3.90262122242741
# Order (Terminal) =  3.756931438258135
#
#
# Iteration: 1000 PDHG error: 2.22530927e-09 spacetime error: 2.75474297e-06 terminal error 1.81047503e-06
#
# Order (ST) =  3.959635930095717
# Order (Terminal) =  3.9923771056025767

# %% [markdown]
# ### Newton's method

# %% [markdown]
# $p=1$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 600
order = 1
for i in range(3):
    H21 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i, nonLinearSolver = "newton")
    if i == 0: print(H21)
    H21.solve()
    H21.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H21.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H21.terminalErr[-1]))
        print("\n")
    err0 = H21.stErr[-1]
    err1 = H21.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 1
#   Degrees of freedom (primal space):  64
#   Degrees of freedom (dual space):  125
#   Non-linear solver: newton
#   PDHG iterations: 600
#
#
# Iteration:  600 PDHG error: 1.41629048e-07 spacetime error: 3.20482292e-02 terminal error 4.33296925e-02
#
# Iteration:  600 PDHG error: 3.52193523e-07 spacetime error: 6.83720591e-03 terminal error 9.43160929e-03
#
# Order (ST) =  2.2287658645635338
# Order (Terminal) =  2.1997801388479394
#
#
# Iteration:  600 PDHG error: 5.58604408e-07 spacetime error: 1.63293905e-03 terminal error 2.27995435e-03
#
# Order (ST) =  2.0659359283920953
# Order (Terminal) =  2.0484990134414893

# %% [markdown]
# $ p = 2$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 800
order = 2
for i in range(3):
    H22 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i, nonLinearSolver = "newton")
    if i == 0: print(H22)
    H22.solve()
    H22.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H22.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H22.terminalErr[-1]))
        print("\n")
    err0 = H22.stErr[-1]
    err1 = H22.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 2
#   Degrees of freedom (primal space):  512
#   Degrees of freedom (dual space):  729
#   Non-linear solver: newton
#   PDHG iterations: 800
#
#
# Iteration:  800 PDHG error: 1.82435631e-08 spacetime error: 5.78213562e-03 terminal error 4.39341287e-03
#
# Iteration:  800 PDHG error: 3.26428657e-08 spacetime error: 9.19274195e-04 terminal error 5.82699403e-04
#
# Order (ST) =  2.653035300397039
# Order (Terminal) =  2.914518343827879
#
#
# Iteration:  800 PDHG error: 5.10130724e-08 spacetime error: 1.19933009e-04 terminal error 7.48425981e-05
#
# Order (ST) =  2.938266462051916
# Order (Terminal) =  2.960820286557834

# %% [markdown]
# $p=3$

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 5))

nIter = 1000
order = 3
for i in range(3):
    H23 = HEAT2D(order = order, maxIter = nIter + 1, beta = beta, nx = nx * 2 ** i, ny = ny * 2 ** i, nz = nz * 2 ** i, nonLinearSolver = "newton")
    if i == 0: print(H23)
    H23.solve()
    H23.plotErr(axs, labels[i], colors[i])
    if i > 0:
        print('Order (ST) = ', np.log2(err0/H23.stErr[-1]))
        print('Order (Terminal) = ', np.log2(err1/H23.terminalErr[-1]))
        print("\n")
    err0 = H23.stErr[-1]
    err1 = H23.terminalErr[-1]
    
axs[0].legend()
plt.show()
# Out:
# Heat Equation
#   C: 1
#   beta: 0.01
#   Time domain: [0, 1]
#   Spatial domain: [0, 1] x [0, 1]
#   Discretization size: 4 x 4 x 4
#   Order: 3
#   Degrees of freedom (primal space):  1728
#   Degrees of freedom (dual space):  2197
#   Non-linear solver: newton
#   PDHG iterations: 1000
#
#
# Iteration: 1000 PDHG error: 1.82446436e-09 spacetime error: 6.40997516e-04 terminal error 3.89553280e-04
#
# Iteration: 1000 PDHG error: 2.31812969e-09 spacetime error: 4.28598058e-05 terminal error 2.88149366e-05
#
# Order (ST) =  3.9026215475668415
# Order (Terminal) =  3.7569319096090803
#
#
# Iteration: 1000 PDHG error: 2.22569896e-09 spacetime error: 2.75474324e-06 terminal error 1.81047271e-06
#
# Order (ST) =  3.9596355499600846
# Order (Terminal) =  3.9923785110486625
