# %%
from FokkerPlanck import FokkerPlanck1D
import matplotlib.pyplot as plt
from ngsolve import *
# %matplotlib widget

# %%
F = FokkerPlanck1D(K=.5,v=5, nx=50, ny=50, nonLinearSolver="brent", brentMin=0, brentMax=6, order=1, beta=.05)
F.draw(F.rho_exact())
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
F.solve()
# Out:
# Iteration: 1000 PDHG error: 1.81352206e-07 spacetime error: 1.34203035e-03 terminal error 9.94577637e-04

# %%
fig, ax = plt.subplots(figsize = (9,6))
F.animate(fig, ax, color='b')

# %%
fig, ax = plt.subplots(figsize = (9,6))
F.snapshots(fig,ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
